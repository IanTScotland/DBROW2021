# %% [markdown]
# <a href="https://colab.research.google.com/github/IanTScotland/DBROW2021/blob/main/AssignmentDataGatheringExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls <- read.csv("https://raw.githubusercontent.com/IanTScotland/DBROW2021/main/chicago-final-count.csv")

# %%
head(ls)
# Out:
#   day crimedate  NUMCRIMES
# 1 1   2001-01-01 1820
# 2 2   2001-01-02 1143
# 3 3   2001-01-03 1151
# 4 4   2001-01-04 1166
# 5 5   2001-01-05 1267
# 6 6   2001-01-06 1290

# %%
summary(ls)
# Out:
#       day         crimedate           NUMCRIMES
#  Min.   :1.000   Length:7373        Min.   : 308.0
#  1st Qu.:2.000   Class :character   1st Qu.: 757.0
#  Median :4.000   Mode  :character   Median : 968.0
#  Mean   :3.999                      Mean   : 989.1
#  3rd Qu.:6.000                      3rd Qu.:1232.0
#  Max.   :7.000                      Max.   :2027.0

# %%
plot(ls$day, ls$NUMCRIMES, main="Number of Crimes vs. Day of the week")
# Out:
# Plot with title “Number of Crimes vs. Day of the week”

# %%
plot(ls$NUMCRIMES, main="Crimes over time")
# Out:
# Plot with title “Crimes over time”

# %%
ssf <- read.csv("https://raw.githubusercontent.com/IanTScotland/DBROW2021/main/chicago-subset-count.csv")

# %%
head(ssf)
# Out:
#   day crimedate  NUMCRIMES
# 1 4   2015-01-01 1221
# 2 5   2015-01-02  673
# 3 6   2015-01-03  648
# 4 7   2015-01-04  514
# 5 1   2015-01-05  523
# 6 2   2015-01-06  503

# %%
summary(ssf)
# Out:
#       day         crimedate           NUMCRIMES
#  Min.   :1.000   Length:1826        Min.   : 341.0
#  1st Qu.:2.000   Class :character   1st Qu.: 677.0
#  Median :4.000   Mode  :character   Median : 733.0
#  Mean   :4.001                      Mean   : 729.3
#  3rd Qu.:6.000                      3rd Qu.: 788.0
#  Max.   :7.000                      Max.   :1221.0

# %%
plot(ssf$day, ssf$NUMCRIMES, main="Number of Crimes vs. Day of the week")
# Out:
# Plot with title “Number of Crimes vs. Day of the week”

# %%
plot(ssf$NUMCRIMES, main="Crimes over time")
# Out:
# Plot with title “Crimes over time”

# %%
fyc <- read.csv("https://raw.githubusercontent.com/IanTScotland/DBROW2021/main/fiveyearsofcrime.csv")

# %%
head(fyc)
# Out:
#   date       year mo da temp dewp slp    visib wdsp mxpsd gust  max min  prcp
# 1 2015-01-01 2015 1  1  22.3  7.3 1020.6 10.0  15.0 18.1   26.0 32   6.1 0.00
# 2 2015-01-02 2015 1  2  28.4 17.4 1024.5 10.0   5.1 15.0   17.1 36  17.1 0.00
# 3 2015-01-03 2015 1  3  34.3 28.9 1017.5  4.9   4.9  8.9  999.9 37  19.9 0.08
# 4 2015-01-04 2015 1  4  30.6 27.5 1013.0  2.9   9.2 18.1   26.0 37  16.0 0.54
# 5 2015-01-05 2015 1  5   4.5 -5.8 1036.3 10.0  11.3 15.0   25.1 14  -0.9 0.03
# 6 2015-01-06 2015 1  6   9.2  1.6 1029.7  6.7   8.0 15.9   24.1 12  -0.9 0.11
#   sndp  fog day crimedate  NUMCRIMES
# 1 999.9 0   4   2015-01-01 1221
# 2 999.9 0   5   2015-01-02  673
# 3 999.9 0   6   2015-01-03  648
# 4   2.0 0   7   2015-01-04  514
# 5   1.2 0   1   2015-01-05  523
# 6   2.0 0   2   2015-01-06  503

# %%
summary(fyc)
# Out:
#      date                year            mo               da
#  Length:1826        Min.   :2015   Min.   : 1.000   Min.   : 1.00
#  Class :character   1st Qu.:2016   1st Qu.: 4.000   1st Qu.: 8.00
#  Mode  :character   Median :2017   Median : 7.000   Median :16.00
#                     Mean   :2017   Mean   : 6.524   Mean   :15.73
#                     3rd Qu.:2018   3rd Qu.:10.000   3rd Qu.:23.00
#                     Max.   :2019   Max.   :12.000   Max.   :31.00
#       temp             dewp             slp             visib
#  Min.   :-13.50   Min.   :-24.60   Min.   : 993.6   Min.   : 1.300
#  1st Qu.: 37.10   1st Qu.: 26.80   1st Qu.:1012.3   1st Qu.: 8.800
#  Median : 53.50   Median : 40.75   Median :1016.5   Median : 9.900
#  Mean   : 52.85   Mean   : 40.87   Mean   :1017.1   Mean   : 9.097
#  3rd Qu.: 70.88   3rd Qu.: 57.40   3rd Qu.:1021.5   3rd Qu.:10.000
#  Max.   : 87.30   Max.   : 77.90   Max.   :1045.3   Max.   :10.000
# ...

# %%
splom(~ fyc[,c(5, 12, 13,17,19)], groups=NULL, data=fyc,
axis.line.tck=0, axis.text.alpha=0)
# Out:
# plot without title
